# %% [markdown]
# # Py 3.6 Notebook
# ## by timofeysie 2020
# ![image.png](attachment:image.png)

# %%
print('Working')
dir ./data/
# Out:
#   File "<ipython-input-7-4606bca7a8c7>", line 2
#     dir ./data/
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from pandasql import sqldf
from pandasql import load_meat, load_bieths
filepath = './data/'
flights = pd.read_csv(filepath + 'data/fpv - Sheet3.csv')

# %%
# !pip list

# %%
import pandas as pd
from pandasql import sqldf
print(sqldf('select * from flights limit 5'))
